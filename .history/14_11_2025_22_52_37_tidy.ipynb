# %% [markdown]
# ## 1. Data Description

# %% [markdown]
# players.csv -> 10 000 observations (rows) and 7 variables (columns)

# %% [markdown]
# sessions.csv -> 20  000 observations (rows) and 5 variables (columns)
